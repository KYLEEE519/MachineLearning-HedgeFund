# %%
import datetime
import pandas as pd
import okx.MarketData as MarketData

def fetch_kline_bt(days, bar, instId, flag="0"):
    """
    获取最近 days 天的K线数据，并转换为 backtrader 兼容的 pandas DataFrame

    参数:
        days (int): 需要的数据天数（例如最近7天）
        bar (str): 时间粒度，如 "1m", "5m", "1H" 等（注意：1s仅支持最近3个月数据）
        instId (str): 产品ID，如 "BTC-USDT"
        flag (str): 实盘："0"，模拟盘："1"

    返回:
        df (DataFrame): 适用于 backtrader 的 DataFrame，包含字段 ['datetime', 'open', 'high', 'low', 'close', 'volume']
                        且 datetime 已设置为索引，数值列已转换为 float 类型
    """
    # 实例化市场数据API对象
    marketDataAPI = MarketData.MarketAPI(flag=flag)
    
    # 当前时间和起始时间（毫秒）
    now = datetime.datetime.now()
    now_ms = int(now.timestamp() * 1000)
    start_ms = now_ms - days * 24 * 3600 * 1000
    
    all_data = []  # 用于存放所有K线数据
    pagination_ts = None  # 分页参数，初始无值表示获取最新100条数据
    
    while True:
        # 构造请求参数
        params = {
            "instId": instId,
            "bar": bar,
            "limit": "100"  # 每次最多返回100条数据
        }
        if pagination_ts is not None:
            params["after"] = pagination_ts
        
        # 调用接口获取历史K线数据
        result = marketDataAPI.get_history_candlesticks(**params)
        
        if result.get("code") != "0":
            print("Error:", result.get("msg"))
            break
        
        data = result.get("data", [])
        if not data:
            break
        
        all_data.extend(data)
        
        # 获取最旧的时间戳
        oldest_ts = int(data[-1][0])
        if oldest_ts <= start_ms:
            break
        
        # 更新分页参数，继续获取更早的数据
        pagination_ts = data[-1][0]
    
    if not all_data:
        print("未获取到数据")
        return pd.DataFrame()
    
    # 定义列名，确保数据顺序正确
    columns = ["datetime", "open", "high", "low", "close", "volume", "volCcy", "volCcyQuote", "confirm"]
    df = pd.DataFrame(all_data, columns=columns)
    
    # 转换 datetime 列为 pandas datetime，并设置为索引
    df["datetime"] = pd.to_datetime(pd.to_numeric(df["datetime"]), unit="ms")
    df.set_index("datetime", inplace=True)

    # 只保留 backtrader 需要的列，并转换数值类型
    df = df[["open", "high", "low", "close", "volume"]]
    df = df.astype(float)  # 确保所有列都是 float 类型
    
    # 过滤出最近 days 天的数据，确保时间范围正确
    df = df[df.index >= pd.to_datetime(start_ms, unit="ms")]
    
    return df

# %%
df = fetch_kline_bt(days=7, bar="5m", instId="BTC-USDT")
print(df.head())
# Out:
#                         open     high      low    close     volume
# datetime
# 2025-03-19 04:45:00  82971.1  83036.0  82952.5  82952.5  19.013236
# 2025-03-19 04:40:00  82956.3  83000.0  82944.5  82971.2  10.715554
# 2025-03-19 04:35:00  82830.8  82956.4  82830.8  82956.4  18.960714
# 2025-03-19 04:30:00  82821.9  82842.5  82786.9  82830.8   5.328271
# 2025-03-19 04:25:00  82906.0  82923.6  82818.1  82822.0   4.597650

# %%
class EnhancedStrategy(bt.Strategy):
    params = (
        ('ma_period', 5),
        ('trade_ratio', 0.9)
    )

    def __init__(self):
        self.sma = bt.indicators.SMA(self.data.close, period=self.p.ma_period)
        self.order = None
        self.trade_count = 0

    def next(self):
        if len(self) < self.p.ma_period:
            return

        if self.order:  # 等待订单完成
            return

        # 多头逻辑
        if self.data.close[0] > self.sma[0]:
            if self.position.size <= 0:
                if self.position.size < 0:
                    self.close()
                self.buy()
        
        # 空头逻辑
        elif self.data.close[0] < self.sma[0]:
            if self.position.size >= 0:
                if self.position.size > 0:
                    self.close()
                self.sell()

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status == order.Completed:
            self.trade_count += 1
            if order.isbuy():
                dir = '买入'
            else:
                dir = '卖出'
            
            print(f'{dir}执行 价格：{order.executed.price:.2f} 数量：{order.executed.size:.6f} 手续费：{order.executed.comm:.4f}')
            self.order = None

def run_backtest():
    cerebro = bt.Cerebro()
    
    # 获取并验证数据
    df = fetch_kline_bt(days=7, bar="5m", instId="BTC-USDT")
    print(f"数据量：{len(df)}条")
    print("最新3条数据：\n", df.tail(3))
    
    data = bt.feeds.PandasData(dataname=df, open=0, high=1, low=2, close=3, volume=4)
    cerebro.adddata(data)

    cerebro.addstrategy(EnhancedStrategy)
    cerebro.broker.setcash(100000)
    cerebro.broker.setcommission(commission=0.0002, commtype=bt.CommInfoBase.COMM_PERC)

    print('初始净值：%.2f' % cerebro.broker.getvalue())
    results = cerebro.run()
    print('最终净值：%.2f' % cerebro.broker.getvalue())
    
    # 分析结果
    strat = results[0]
    print('总交易次数：', strat.trade_count)
    cerebro.plot(style='candlestick')

if __name__ == '__main__':
    run_backtest()
# Out:
# 数据量：2015条
# 最新3条数据：
#                          open     high      low    close     volume
# datetime
# 2025-03-19 05:15:00  82921.9  83015.7  82921.9  83003.3  15.437916
# 2025-03-19 05:20:00  83003.4  83038.0  82987.1  83038.0  25.807545
# 2025-03-19 05:25:00  83037.9  83112.8  83000.3  83038.1  31.827067
# 初始净值：100000.00
# 买入执行 价格：81976.60 数量：1.000000 手续费：16.3953
# 卖出执行 价格：81783.00 数量：-1.000000 手续费：16.3566
# 卖出执行 价格：81783.00 数量：-1.000000 手续费：16.3566
# 买入执行 价格：81688.50 数量：1.000000 手续费：16.3377
# 买入执行 价格：81688.50 数量：1.000000 手续费：16.3377
# 卖出执行 价格：81648.60 数量：-1.000000 手续费：16.3297
# 卖出执行 价格：81648.60 数量：-1.000000 手续费：16.3297
# 买入执行 价格：81477.70 数量：1.000000 手续费：16.2955
# 买入执行 价格：81477.70 数量：1.000000 手续费：16.2955
# 卖出执行 价格：81466.60 数量：-1.000000 手续费：16.2933
# 卖出执行 价格：81466.60 数量：-1.000000 手续费：16.2933
# 买入执行 价格：81530.30 数量：1.000000 手续费：16.3061
# 买入执行 价格：81530.30 数量：1.000000 手续费：16.3061
# 卖出执行 价格：82428.00 数量：-1.000000 手续费：16.4856
# 卖出执行 价格：82428.00 数量：-1.000000 手续费：16.4856
# 买入执行 价格：82522.00 数量：1.000000 手续费：16.5044
# 买入执行 价格：82522.00 数量：1.000000 手续费：16.5044
# 卖出执行 价格：82441.50 数量：-1.000000 手续费：16.4883
# 卖出执行 价格：82441.50 数量：-1.000000 手续费：16.4883
# 买入执行 价格：82600.30 数量：1.000000 手续费：16.5201
# 买入执行 价格：82600.30 数量：1.000000 手续费：16.5201
# 卖出执行 价格：82604.60 数量：-1.000000 手续费：16.5209
# 卖出执行 价格：82604.60 数量：-1.000000 手续费：16.5209
# 买入执行 价格：82688.80 数量：1.000000 手续费：16.5378
# 买入执行 价格：82688.80 数量：1.000000 手续费：16.5378
# 卖出执行 价格：82569.20 数量：-1.000000 手续费：16.5138
# 卖出执行 价格：82569.20 数量：-1.000000 手续费：16.5138
# 买入执行 价格：82439.20 数量：1.000000 手续费：16.4878
# 买入执行 价格：82439.20 数量：1.000000 手续费：16.4878
# 卖出执行 价格：82554.10 数量：-1.000000 手续费：16.5108
# 卖出执行 价格：82554.10 数量：-1.000000 手续费：16.5108
# 买入执行 价格：82299.30 数量：1.000000 手续费：16.4599
# 买入执行 价格：82299.30 数量：1.000000 手续费：16.4599
# 卖出执行 价格：82500.00 数量：-1.000000 手续费：16.5000
# 卖出执行 价格：82500.00 数量：-1.000000 手续费：16.5000
# 买入执行 价格：82584.30 数量：1.000000 手续费：16.5169
# 买入执行 价格：82584.30 数量：1.000000 手续费：16.5169
# 卖出执行 价格：82975.00 数量：-1.000000 手续费：16.5950
# 卖出执行 价格：82975.00 数量：-1.000000 手续费：16.5950
# 买入执行 价格：83060.00 数量：1.000000 手续费：16.6120
# 买入执行 价格：83060.00 数量：1.000000 手续费：16.6120
# 卖出执行 价格：83813.70 数量：-1.000000 手续费：16.7627
# 卖出执行 价格：83813.70 数量：-1.000000 手续费：16.7627
# 买入执行 价格：83590.10 数量：1.000000 手续费：16.7180
# 买入执行 价格：83590.10 数量：1.000000 手续费：16.7180
# 卖出执行 价格：83057.80 数量：-1.000000 手续费：16.6116
# 卖出执行 价格：83057.80 数量：-1.000000 手续费：16.6116
# 买入执行 价格：81858.00 数量：1.000000 手续费：16.3716
# 买入执行 价格：81858.00 数量：1.000000 手续费：16.3716
# 卖出执行 价格：81531.90 数量：-1.000000 手续费：16.3064
# 卖出执行 价格：81531.90 数量：-1.000000 手续费：16.3064
# 买入执行 价格：81118.00 数量：1.000000 手续费：16.2236
# 买入执行 价格：81118.00 数量：1.000000 手续费：16.2236
# 卖出执行 价格：81731.80 数量：-1.000000 手续费：16.3464
# 卖出执行 价格：81731.80 数量：-1.000000 手续费：16.3464
# 买入执行 价格：81875.90 数量：1.000000 手续费：16.3752
# 买入执行 价格：81875.90 数量：1.000000 手续费：16.3752
# 卖出执行 价格：81973.00 数量：-1.000000 手续费：16.3946
# 卖出执行 价格：81973.00 数量：-1.000000 手续费：16.3946
# 买入执行 价格：82085.90 数量：1.000000 手续费：16.4172
# 买入执行 价格：82085.90 数量：1.000000 手续费：16.4172
# 卖出执行 价格：81662.00 数量：-1.000000 手续费：16.3324
# 卖出执行 价格：81662.00 数量：-1.000000 手续费：16.3324
# 买入执行 价格：82022.20 数量：1.000000 手续费：16.4044
# 买入执行 价格：82022.20 数量：1.000000 手续费：16.4044
# 卖出执行 价格：81939.60 数量：-1.000000 手续费：16.3879
# 卖出执行 价格：81939.60 数量：-1.000000 手续费：16.3879
# 买入执行 价格：81973.00 数量：1.000000 手续费：16.3946
# 买入执行 价格：81973.00 数量：1.000000 手续费：16.3946
# 卖出执行 价格：82602.00 数量：-1.000000 手续费：16.5204
# 卖出执行 价格：82602.00 数量：-1.000000 手续费：16.5204
# 买入执行 价格：82079.50 数量：1.000000 手续费：16.4159
# 买入执行 价格：82079.50 数量：1.000000 手续费：16.4159
# 卖出执行 价格：82596.20 数量：-1.000000 手续费：16.5192
# 卖出执行 价格：82596.20 数量：-1.000000 手续费：16.5192
# 买入执行 价格：82767.00 数量：1.000000 手续费：16.5534
# 买入执行 价格：82767.00 数量：1.000000 手续费：16.5534
# 卖出执行 价格：82771.70 数量：-1.000000 手续费：16.5543
# 卖出执行 价格：82771.70 数量：-1.000000 手续费：16.5543
# 买入执行 价格：82934.40 数量：1.000000 手续费：16.5869
# 买入执行 价格：82934.40 数量：1.000000 手续费：16.5869
# 卖出执行 价格：82643.30 数量：-1.000000 手续费：16.5287
# 卖出执行 价格：82643.30 数量：-1.000000 手续费：16.5287
# 买入执行 价格：82880.00 数量：1.000000 手续费：16.5760
# 买入执行 价格：82880.00 数量：1.000000 手续费：16.5760
# 卖出执行 价格：82829.20 数量：-1.000000 手续费：16.5658
# 卖出执行 价格：82829.20 数量：-1.000000 手续费：16.5658
# 买入执行 价格：82953.10 数量：1.000000 手续费：16.5906
# 买入执行 价格：82953.10 数量：1.000000 手续费：16.5906
# 卖出执行 价格：83043.60 数量：-1.000000 手续费：16.6087
# 卖出执行 价格：83043.60 数量：-1.000000 手续费：16.6087
# 买入执行 价格：83117.50 数量：1.000000 手续费：16.6235
# 买入执行 价格：83117.50 数量：1.000000 手续费：16.6235
# 卖出执行 价格：83213.50 数量：-1.000000 手续费：16.6427
# 卖出执行 价格：83213.50 数量：-1.000000 手续费：16.6427
# 买入执行 价格：83086.40 数量：1.000000 手续费：16.6173
# 买入执行 价格：83086.40 数量：1.000000 手续费：16.6173
# 卖出执行 价格：83556.00 数量：-1.000000 手续费：16.7112
# 卖出执行 价格：83556.00 数量：-1.000000 手续费：16.7112
# 买入执行 价格：83690.50 数量：1.000000 手续费：16.7381
# 买入执行 价格：83690.50 数量：1.000000 手续费：16.7381
# 卖出执行 价格：83525.30 数量：-1.000000 手续费：16.7051
# 卖出执行 价格：83525.30 数量：-1.000000 手续费：16.7051
# 买入执行 价格：83536.50 数量：1.000000 手续费：16.7073
# 买入执行 价格：83536.50 数量：1.000000 手续费：16.7073
# 卖出执行 价格：83691.90 数量：-1.000000 手续费：16.7384
# 卖出执行 价格：83691.90 数量：-1.000000 手续费：16.7384
# 买入执行 价格：83801.10 数量：1.000000 手续费：16.7602
# 买入执行 价格：83801.10 数量：1.000000 手续费：16.7602
# 卖出执行 价格：83671.60 数量：-1.000000 手续费：16.7343
# 卖出执行 价格：83671.60 数量：-1.000000 手续费：16.7343
# 买入执行 价格：83868.10 数量：1.000000 手续费：16.7736
# 买入执行 价格：83868.10 数量：1.000000 手续费：16.7736
# 卖出执行 价格：83606.90 数量：-1.000000 手续费：16.7214
# 卖出执行 价格：83606.90 数量：-1.000000 手续费：16.7214
# 买入执行 价格：83564.10 数量：1.000000 手续费：16.7128
# 买入执行 价格：83564.10 数量：1.000000 手续费：16.7128
# 卖出执行 价格：83541.10 数量：-1.000000 手续费：16.7082
# 卖出执行 价格：83541.10 数量：-1.000000 手续费：16.7082
# 买入执行 价格：83646.40 数量：1.000000 手续费：16.7293
# 买入执行 价格：83646.40 数量：1.000000 手续费：16.7293
# 卖出执行 价格：84015.50 数量：-1.000000 手续费：16.8031
# 卖出执行 价格：84015.50 数量：-1.000000 手续费：16.8031
# 买入执行 价格：83952.00 数量：1.000000 手续费：16.7904
# 买入执行 价格：83952.00 数量：1.000000 手续费：16.7904
# 卖出执行 价格：83874.90 数量：-1.000000 手续费：16.7750
# 卖出执行 价格：83874.90 数量：-1.000000 手续费：16.7750
# 买入执行 价格：83963.00 数量：1.000000 手续费：16.7926
# 买入执行 价格：83963.00 数量：1.000000 手续费：16.7926
# 卖出执行 价格：83892.70 数量：-1.000000 手续费：16.7785
# 卖出执行 价格：83892.70 数量：-1.000000 手续费：16.7785
# 买入执行 价格：83614.00 数量：1.000000 手续费：16.7228
# 买入执行 价格：83614.00 数量：1.000000 手续费：16.7228
# 卖出执行 价格：83459.00 数量：-1.000000 手续费：16.6918
# 卖出执行 价格：83459.00 数量：-1.000000 手续费：16.6918
# 买入执行 价格：83431.30 数量：1.000000 手续费：16.6863
# 买入执行 价格：83431.30 数量：1.000000 手续费：16.6863
# 卖出执行 价格：83289.50 数量：-1.000000 手续费：16.6579
# 卖出执行 价格：83289.50 数量：-1.000000 手续费：16.6579
# 买入执行 价格：83406.80 数量：1.000000 手续费：16.6814
# 买入执行 价格：83406.80 数量：1.000000 手续费：16.6814
# 卖出执行 价格：83329.90 数量：-1.000000 手续费：16.6660
# 卖出执行 价格：83329.90 数量：-1.000000 手续费：16.6660
# 买入执行 价格：83371.30 数量：1.000000 手续费：16.6743
# 买入执行 价格：83371.30 数量：1.000000 手续费：16.6743
# 卖出执行 价格：83310.30 数量：-1.000000 手续费：16.6621
# 卖出执行 价格：83310.30 数量：-1.000000 手续费：16.6621
# 买入执行 价格：83157.60 数量：1.000000 手续费：16.6315
# 买入执行 价格：83157.60 数量：1.000000 手续费：16.6315
# 卖出执行 价格：83079.60 数量：-1.000000 手续费：16.6159
# 卖出执行 价格：83079.60 数量：-1.000000 手续费：16.6159
# 买入执行 价格：83018.50 数量：1.000000 手续费：16.6037
# 买入执行 价格：83018.50 数量：1.000000 手续费：16.6037
# 卖出执行 价格：83180.00 数量：-1.000000 手续费：16.6360
# 卖出执行 价格：83180.00 数量：-1.000000 手续费：16.6360
# 买入执行 价格：83280.00 数量：1.000000 手续费：16.6560
# 买入执行 价格：83280.00 数量：1.000000 手续费：16.6560
# 卖出执行 价格：83238.20 数量：-1.000000 手续费：16.6476
# 卖出执行 价格：83238.20 数量：-1.000000 手续费：16.6476
# 买入执行 价格：82819.10 数量：1.000000 手续费：16.5638
# 买入执行 价格：82819.10 数量：1.000000 手续费：16.5638
# 卖出执行 价格：83309.90 数量：-1.000000 手续费：16.6620
# 卖出执行 价格：83309.90 数量：-1.000000 手续费：16.6620
# 买入执行 价格：83416.10 数量：1.000000 手续费：16.6832
# 买入执行 价格：83416.10 数量：1.000000 手续费：16.6832
# 卖出执行 价格：83348.30 数量：-1.000000 手续费：16.6697
# 卖出执行 价格：83348.30 数量：-1.000000 手续费：16.6697
# 买入执行 价格：83437.40 数量：1.000000 手续费：16.6875
# 买入执行 价格：83437.40 数量：1.000000 手续费：16.6875
# 卖出执行 价格：83289.50 数量：-1.000000 手续费：16.6579
# 卖出执行 价格：83289.50 数量：-1.000000 手续费：16.6579
# 买入执行 价格：83297.00 数量：1.000000 手续费：16.6594
# 买入执行 价格：83297.00 数量：1.000000 手续费：16.6594
# 卖出执行 价格：83100.00 数量：-1.000000 手续费：16.6200
# 卖出执行 价格：83100.00 数量：-1.000000 手续费：16.6200
# 买入执行 价格：83231.70 数量：1.000000 手续费：16.6463
# 买入执行 价格：83231.70 数量：1.000000 手续费：16.6463
# 卖出执行 价格：83091.70 数量：-1.000000 手续费：16.6183
# 卖出执行 价格：83091.70 数量：-1.000000 手续费：16.6183
# 买入执行 价格：83002.00 数量：1.000000 手续费：16.6004
# 买入执行 价格：83002.00 数量：1.000000 手续费：16.6004
# 卖出执行 价格：82780.40 数量：-1.000000 手续费：16.5561
# 卖出执行 价格：82780.40 数量：-1.000000 手续费：16.5561
# 买入执行 价格：82970.40 数量：1.000000 手续费：16.5941
# 买入执行 价格：82970.40 数量：1.000000 手续费：16.5941
# 卖出执行 价格：82863.10 数量：-1.000000 手续费：16.5726
# 卖出执行 价格：82863.10 数量：-1.000000 手续费：16.5726
# 买入执行 价格：83025.30 数量：1.000000 手续费：16.6051
# 买入执行 价格：83025.30 数量：1.000000 手续费：16.6051
# 卖出执行 价格：83074.00 数量：-1.000000 手续费：16.6148
# 卖出执行 价格：83074.00 数量：-1.000000 手续费：16.6148
# 买入执行 价格：82862.10 数量：1.000000 手续费：16.5724
# 买入执行 价格：82862.10 数量：1.000000 手续费：16.5724
# 卖出执行 价格：82600.90 数量：-1.000000 手续费：16.5202
# 卖出执行 价格：82600.90 数量：-1.000000 手续费：16.5202
# 买入执行 价格：82777.10 数量：1.000000 手续费：16.5554
# 买入执行 价格：82777.10 数量：1.000000 手续费：16.5554
# 卖出执行 价格：82525.90 数量：-1.000000 手续费：16.5052
# 卖出执行 价格：82525.90 数量：-1.000000 手续费：16.5052
# 买入执行 价格：82060.80 数量：1.000000 手续费：16.4122
# 买入执行 价格：82060.80 数量：1.000000 手续费：16.4122
# 卖出执行 价格：81899.80 数量：-1.000000 手续费：16.3800
# 卖出执行 价格：81899.80 数量：-1.000000 手续费：16.3800
# 买入执行 价格：82180.40 数量：1.000000 手续费：16.4361
# 买入执行 价格：82180.40 数量：1.000000 手续费：16.4361
# 卖出执行 价格：82010.20 数量：-1.000000 手续费：16.4020
# 卖出执行 价格：82010.20 数量：-1.000000 手续费：16.4020
# 买入执行 价格：81822.20 数量：1.000000 手续费：16.3644
# 买入执行 价格：81822.20 数量：1.000000 手续费：16.3644
# 卖出执行 价格：81596.00 数量：-1.000000 手续费：16.3192
# 卖出执行 价格：81596.00 数量：-1.000000 手续费：16.3192
# 买入执行 价格：81068.30 数量：1.000000 手续费：16.2137
# 买入执行 价格：81068.30 数量：1.000000 手续费：16.2137
# 卖出执行 价格：80949.20 数量：-1.000000 手续费：16.1898
# 卖出执行 价格：80949.20 数量：-1.000000 手续费：16.1898
# 买入执行 价格：81017.80 数量：1.000000 手续费：16.2036
# 买入执行 价格：81017.80 数量：1.000000 手续费：16.2036
# 卖出执行 价格：81022.80 数量：-1.000000 手续费：16.2046
# 卖出执行 价格：81022.80 数量：-1.000000 手续费：16.2046
# 买入执行 价格：80175.50 数量：1.000000 手续费：16.0351
# 买入执行 价格：80175.50 数量：1.000000 手续费：16.0351
# 卖出执行 价格：80066.50 数量：-1.000000 手续费：16.0133
# 卖出执行 价格：80066.50 数量：-1.000000 手续费：16.0133
# 买入执行 价格：80360.00 数量：1.000000 手续费：16.0720
# 买入执行 价格：80360.00 数量：1.000000 手续费：16.0720
# 卖出执行 价格：80769.00 数量：-1.000000 手续费：16.1538
# 卖出执行 价格：80769.00 数量：-1.000000 手续费：16.1538
# 买入执行 价格：80832.00 数量：1.000000 手续费：16.1664
# 买入执行 价格：80832.00 数量：1.000000 手续费：16.1664
# 卖出执行 价格：80746.50 数量：-1.000000 手续费：16.1493
# 卖出执行 价格：80746.50 数量：-1.000000 手续费：16.1493
# 买入执行 价格：80822.10 数量：1.000000 手续费：16.1644
# 买入执行 价格：80822.10 数量：1.000000 手续费：16.1644
# 卖出执行 价格：80741.40 数量：-1.000000 手续费：16.1483
# 卖出执行 价格：80741.40 数量：-1.000000 手续费：16.1483
# 买入执行 价格：80494.40 数量：1.000000 手续费：16.0989
# 买入执行 价格：80494.40 数量：1.000000 手续费：16.0989
# 卖出执行 价格：80387.00 数量：-1.000000 手续费：16.0774
# 卖出执行 价格：80387.00 数量：-1.000000 手续费：16.0774
# 买入执行 价格：80377.30 数量：1.000000 手续费：16.0755
# 买入执行 价格：80377.30 数量：1.000000 手续费：16.0755
# 卖出执行 价格：80524.90 数量：-1.000000 手续费：16.1050
# 卖出执行 价格：80524.90 数量：-1.000000 手续费：16.1050
# 买入执行 价格：80653.90 数量：1.000000 手续费：16.1308
# 买入执行 价格：80653.90 数量：1.000000 手续费：16.1308
# 卖出执行 价格：80688.80 数量：-1.000000 手续费：16.1378
# 卖出执行 价格：80688.80 数量：-1.000000 手续费：16.1378
# 买入执行 价格：80819.90 数量：1.000000 手续费：16.1640
# 买入执行 价格：80819.90 数量：1.000000 手续费：16.1640
# 卖出执行 价格：80842.40 数量：-1.000000 手续费：16.1685
# 卖出执行 价格：80842.40 数量：-1.000000 手续费：16.1685
# 买入执行 价格：80945.20 数量：1.000000 手续费：16.1890
# 买入执行 价格：80945.20 数量：1.000000 手续费：16.1890
# 卖出执行 价格：81363.60 数量：-1.000000 手续费：16.2727
# 卖出执行 价格：81363.60 数量：-1.000000 手续费：16.2727
# 买入执行 价格：81182.70 数量：1.000000 手续费：16.2365
# 买入执行 价格：81182.70 数量：1.000000 手续费：16.2365
# 卖出执行 价格：81119.60 数量：-1.000000 手续费：16.2239
# 卖出执行 价格：81119.60 数量：-1.000000 手续费：16.2239
# 买入执行 价格：81060.10 数量：1.000000 手续费：16.2120
# 买入执行 价格：81060.10 数量：1.000000 手续费：16.2120
# 卖出执行 价格：81334.20 数量：-1.000000 手续费：16.2668
# 卖出执行 价格：81334.20 数量：-1.000000 手续费：16.2668
# 买入执行 价格：81364.20 数量：1.000000 手续费：16.2728
# 买入执行 价格：81364.20 数量：1.000000 手续费：16.2728
# 卖出执行 价格：81686.00 数量：-1.000000 手续费：16.3372
# 卖出执行 价格：81686.00 数量：-1.000000 手续费：16.3372
# 买入执行 价格：81726.30 数量：1.000000 手续费：16.3453
# 买入执行 价格：81726.30 数量：1.000000 手续费：16.3453
# 卖出执行 价格：81844.90 数量：-1.000000 手续费：16.3690
# 卖出执行 价格：81844.90 数量：-1.000000 手续费：16.3690
# 买入执行 价格：81987.90 数量：1.000000 手续费：16.3976
# 买入执行 价格：81987.90 数量：1.000000 手续费：16.3976
# 卖出执行 价格：82032.10 数量：-1.000000 手续费：16.4064
# 卖出执行 价格：82032.10 数量：-1.000000 手续费：16.4064
# 买入执行 价格：82105.80 数量：1.000000 手续费：16.4212
# 买入执行 价格：82105.80 数量：1.000000 手续费：16.4212
# 卖出执行 价格：82047.90 数量：-1.000000 手续费：16.4096
# 卖出执行 价格：82047.90 数量：-1.000000 手续费：16.4096
# 买入执行 价格：81899.20 数量：1.000000 手续费：16.3798
# 买入执行 价格：81899.20 数量：1.000000 手续费：16.3798
# 卖出执行 价格：81937.10 数量：-1.000000 手续费：16.3874
# 卖出执行 价格：81937.10 数量：-1.000000 手续费：16.3874
# 买入执行 价格：81980.40 数量：1.000000 手续费：16.3961
# 买入执行 价格：81980.40 数量：1.000000 手续费：16.3961
# 卖出执行 价格：81947.40 数量：-1.000000 手续费：16.3895
# 卖出执行 价格：81947.40 数量：-1.000000 手续费：16.3895
# 买入执行 价格：81954.00 数量：1.000000 手续费：16.3908
# 买入执行 价格：81954.00 数量：1.000000 手续费：16.3908
# 卖出执行 价格：81837.00 数量：-1.000000 手续费：16.3674
# 卖出执行 价格：81837.00 数量：-1.000000 手续费：16.3674
# 买入执行 价格：81950.10 数量：1.000000 手续费：16.3900
# 买入执行 价格：81950.10 数量：1.000000 手续费：16.3900
# 卖出执行 价格：82095.40 数量：-1.000000 手续费：16.4191
# 卖出执行 价格：82095.40 数量：-1.000000 手续费：16.4191
# 买入执行 价格：81955.40 数量：1.000000 手续费：16.3911
# 买入执行 价格：81955.40 数量：1.000000 手续费：16.3911
# 卖出执行 价格：81869.80 数量：-1.000000 手续费：16.3740
# 卖出执行 价格：81869.80 数量：-1.000000 手续费：16.3740
# 买入执行 价格：81924.10 数量：1.000000 手续费：16.3848
# 买入执行 价格：81924.10 数量：1.000000 手续费：16.3848
# 卖出执行 价格：81909.80 数量：-1.000000 手续费：16.3820
# 卖出执行 价格：81909.80 数量：-1.000000 手续费：16.3820
# 买入执行 价格：82018.00 数量：1.000000 手续费：16.4036
# 买入执行 价格：82018.00 数量：1.000000 手续费：16.4036
# 卖出执行 价格：82178.60 数量：-1.000000 手续费：16.4357
# 卖出执行 价格：82178.60 数量：-1.000000 手续费：16.4357
# 买入执行 价格：82298.40 数量：1.000000 手续费：16.4597
# 买入执行 价格：82298.40 数量：1.000000 手续费：16.4597
# 卖出执行 价格：82348.00 数量：-1.000000 手续费：16.4696
# 卖出执行 价格：82348.00 数量：-1.000000 手续费：16.4696
# 买入执行 价格：82512.20 数量：1.000000 手续费：16.5024
# 买入执行 价格：82512.20 数量：1.000000 手续费：16.5024
# 卖出执行 价格：82650.10 数量：-1.000000 手续费：16.5300
# 卖出执行 价格：82650.10 数量：-1.000000 手续费：16.5300
# 买入执行 价格：82787.90 数量：1.000000 手续费：16.5576
# 买入执行 价格：82787.90 数量：1.000000 手续费：16.5576
# 卖出执行 价格：82711.00 数量：-1.000000 手续费：16.5422
# 卖出执行 价格：82711.00 数量：-1.000000 手续费：16.5422
# 买入执行 价格：82890.00 数量：1.000000 手续费：16.5780
# 买入执行 价格：82890.00 数量：1.000000 手续费：16.5780
# 卖出执行 价格：82798.00 数量：-1.000000 手续费：16.5596
# 卖出执行 价格：82798.00 数量：-1.000000 手续费：16.5596
# 买入执行 价格：82840.00 数量：1.000000 手续费：16.5680
# 买入执行 价格：82840.00 数量：1.000000 手续费：16.5680
# 卖出执行 价格：82781.60 数量：-1.000000 手续费：16.5563
# 卖出执行 价格：82781.60 数量：-1.000000 手续费：16.5563
# 买入执行 价格：82812.00 数量：1.000000 手续费：16.5624
# 买入执行 价格：82812.00 数量：1.000000 手续费：16.5624
# 卖出执行 价格：83048.20 数量：-1.000000 手续费：16.6096
# 卖出执行 价格：83048.20 数量：-1.000000 手续费：16.6096
# 买入执行 价格：83113.70 数量：1.000000 手续费：16.6227
# 买入执行 价格：83113.70 数量：1.000000 手续费：16.6227
# 卖出执行 价格：83081.10 数量：-1.000000 手续费：16.6162
# 卖出执行 价格：83081.10 数量：-1.000000 手续费：16.6162
# 买入执行 价格：83202.00 数量：1.000000 手续费：16.6404
# 买入执行 价格：83202.00 数量：1.000000 手续费：16.6404
# 卖出执行 价格：83236.00 数量：-1.000000 手续费：16.6472
# 卖出执行 价格：83236.00 数量：-1.000000 手续费：16.6472
# 买入执行 价格：83415.90 数量：1.000000 手续费：16.6832
# 买入执行 价格：83415.90 数量：1.000000 手续费：16.6832
# 卖出执行 价格：83411.90 数量：-1.000000 手续费：16.6824
# 卖出执行 价格：83411.90 数量：-1.000000 手续费：16.6824
# 买入执行 价格：83356.20 数量：1.000000 手续费：16.6712
# 买入执行 价格：83356.20 数量：1.000000 手续费：16.6712
# 卖出执行 价格：83395.70 数量：-1.000000 手续费：16.6791
# 卖出执行 价格：83395.70 数量：-1.000000 手续费：16.6791
# 买入执行 价格：83688.00 数量：1.000000 手续费：16.7376
# 买入执行 价格：83688.00 数量：1.000000 手续费：16.7376
# 卖出执行 价格：83270.00 数量：-1.000000 手续费：16.6540
# 卖出执行 价格：83270.00 数量：-1.000000 手续费：16.6540
# 买入执行 价格：83844.00 数量：1.000000 手续费：16.7688
# 买入执行 价格：83844.00 数量：1.000000 手续费：16.7688
# 卖出执行 价格：83357.90 数量：-1.000000 手续费：16.6716
# 卖出执行 价格：83357.90 数量：-1.000000 手续费：16.6716
# 买入执行 价格：82931.80 数量：1.000000 手续费：16.5864
# 买入执行 价格：82931.80 数量：1.000000 手续费：16.5864
# 卖出执行 价格：84782.10 数量：-1.000000 手续费：16.9564
# 卖出执行 价格：84782.10 数量：-1.000000 手续费：16.9564
# 买入执行 价格：84688.00 数量：1.000000 手续费：16.9376
# 买入执行 价格：84688.00 数量：1.000000 手续费：16.9376
# 卖出执行 价格：84403.20 数量：-1.000000 手续费：16.8806
# 卖出执行 价格：84403.20 数量：-1.000000 手续费：16.8806
# 买入执行 价格：84485.70 数量：1.000000 手续费：16.8971
# 买入执行 价格：84485.70 数量：1.000000 手续费：16.8971
# 卖出执行 价格：84624.10 数量：-1.000000 手续费：16.9248
# 卖出执行 价格：84624.10 数量：-1.000000 手续费：16.9248
# 买入执行 价格：84671.30 数量：1.000000 手续费：16.9343
# 买入执行 价格：84671.30 数量：1.000000 手续费：16.9343
# 卖出执行 价格：84560.00 数量：-1.000000 手续费：16.9120
# 卖出执行 价格：84560.00 数量：-1.000000 手续费：16.9120
# 买入执行 价格：84399.40 数量：1.000000 手续费：16.8799
# 买入执行 价格：84399.40 数量：1.000000 手续费：16.8799
# 卖出执行 价格：84229.40 数量：-1.000000 手续费：16.8459
# 卖出执行 价格：84229.40 数量：-1.000000 手续费：16.8459
# 买入执行 价格：84306.10 数量：1.000000 手续费：16.8612
# 买入执行 价格：84306.10 数量：1.000000 手续费：16.8612
# 卖出执行 价格：84415.40 数量：-1.000000 手续费：16.8831
# 卖出执行 价格：84415.40 数量：-1.000000 手续费：16.8831
# 买入执行 价格：84429.20 数量：1.000000 手续费：16.8858
# 买入执行 价格：84429.20 数量：1.000000 手续费：16.8858
# 卖出执行 价格：84557.90 数量：-1.000000 手续费：16.9116
# 卖出执行 价格：84557.90 数量：-1.000000 手续费：16.9116
# 买入执行 价格：84619.20 数量：1.000000 手续费：16.9238
# 买入执行 价格：84619.20 数量：1.000000 手续费：16.9238
# 卖出执行 价格：84659.90 数量：-1.000000 手续费：16.9320
# 卖出执行 价格：84659.90 数量：-1.000000 手续费：16.9320
# 买入执行 价格：84189.90 数量：1.000000 手续费：16.8380
# 买入执行 价格：84189.90 数量：1.000000 手续费：16.8380
# 卖出执行 价格：84136.00 数量：-1.000000 手续费：16.8272
# 卖出执行 价格：84136.00 数量：-1.000000 手续费：16.8272
# 买入执行 价格：84138.40 数量：1.000000 手续费：16.8277
# 买入执行 价格：84138.40 数量：1.000000 手续费：16.8277
# 卖出执行 价格：84216.90 数量：-1.000000 手续费：16.8434
# 卖出执行 价格：84216.90 数量：-1.000000 手续费：16.8434
# 买入执行 价格：84215.00 数量：1.000000 手续费：16.8430
# 买入执行 价格：84215.00 数量：1.000000 手续费：16.8430
# 卖出执行 价格：84168.80 数量：-1.000000 手续费：16.8338
# 卖出执行 价格：84168.80 数量：-1.000000 手续费：16.8338
# 买入执行 价格：84397.20 数量：1.000000 手续费：16.8794
# 买入执行 价格：84397.20 数量：1.000000 手续费：16.8794
# 卖出执行 价格：84303.20 数量：-1.000000 手续费：16.8606
# 卖出执行 价格：84303.20 数量：-1.000000 手续费：16.8606
# 买入执行 价格：84381.50 数量：1.000000 手续费：16.8763
# 买入执行 价格：84381.50 数量：1.000000 手续费：16.8763
# 卖出执行 价格：84387.90 数量：-1.000000 手续费：16.8776
# 卖出执行 价格：84387.90 数量：-1.000000 手续费：16.8776
# 买入执行 价格：84268.40 数量：1.000000 手续费：16.8537
# 买入执行 价格：84268.40 数量：1.000000 手续费：16.8537
# 卖出执行 价格：84128.00 数量：-1.000000 手续费：16.8256
# 卖出执行 价格：84128.00 数量：-1.000000 手续费：16.8256
# 买入执行 价格：84063.90 数量：1.000000 手续费：16.8128
# 买入执行 价格：84063.90 数量：1.000000 手续费：16.8128
# 卖出执行 价格：84122.00 数量：-1.000000 手续费：16.8244
# 卖出执行 价格：84122.00 数量：-1.000000 手续费：16.8244
# 买入执行 价格：84231.50 数量：1.000000 手续费：16.8463
# 买入执行 价格：84231.50 数量：1.000000 手续费：16.8463
# 卖出执行 价格：84403.70 数量：-1.000000 手续费：16.8807
# 卖出执行 价格：84403.70 数量：-1.000000 手续费：16.8807
# 买入执行 价格：84296.90 数量：1.000000 手续费：16.8594
# 买入执行 价格：84296.90 数量：1.000000 手续费：16.8594
# 卖出执行 价格：84229.90 数量：-1.000000 手续费：16.8460
# 卖出执行 价格：84229.90 数量：-1.000000 手续费：16.8460
# 买入执行 价格：84391.60 数量：1.000000 手续费：16.8783
# 买入执行 价格：84391.60 数量：1.000000 手续费：16.8783
# 卖出执行 价格：84310.00 数量：-1.000000 手续费：16.8620
# 卖出执行 价格：84310.00 数量：-1.000000 手续费：16.8620
# 买入执行 价格：84338.10 数量：1.000000 手续费：16.8676
# 买入执行 价格：84338.10 数量：1.000000 手续费：16.8676
# 卖出执行 价格：84503.30 数量：-1.000000 手续费：16.9007
# 卖出执行 价格：84503.30 数量：-1.000000 手续费：16.9007
# 买入执行 价格：84543.60 数量：1.000000 手续费：16.9087
# 买入执行 价格：84543.60 数量：1.000000 手续费：16.9087
# 卖出执行 价格：84518.00 数量：-1.000000 手续费：16.9036
# 卖出执行 价格：84518.00 数量：-1.000000 手续费：16.9036
# 买入执行 价格：84485.00 数量：1.000000 手续费：16.8970
# 买入执行 价格：84485.00 数量：1.000000 手续费：16.8970
# 卖出执行 价格：84444.40 数量：-1.000000 手续费：16.8889
# 卖出执行 价格：84444.40 数量：-1.000000 手续费：16.8889
# 买入执行 价格：84393.50 数量：1.000000 手续费：16.8787
# 买入执行 价格：84393.50 数量：1.000000 手续费：16.8787
# 卖出执行 价格：84469.20 数量：-1.000000 手续费：16.8938
# 卖出执行 价格：84469.20 数量：-1.000000 手续费：16.8938
# 买入执行 价格：84377.90 数量：1.000000 手续费：16.8756
# 买入执行 价格：84377.90 数量：1.000000 手续费：16.8756
# 卖出执行 价格：84316.10 数量：-1.000000 手续费：16.8632
# 卖出执行 价格：84316.10 数量：-1.000000 手续费：16.8632
# 买入执行 价格：84268.00 数量：1.000000 手续费：16.8536
# 买入执行 价格：84268.00 数量：1.000000 手续费：16.8536
# 卖出执行 价格：84206.90 数量：-1.000000 手续费：16.8414
# 卖出执行 价格：84206.90 数量：-1.000000 手续费：16.8414
# 买入执行 价格：84245.90 数量：1.000000 手续费：16.8492
# 买入执行 价格：84245.90 数量：1.000000 手续费：16.8492
# 卖出执行 价格：84195.90 数量：-1.000000 手续费：16.8392
# 卖出执行 价格：84195.90 数量：-1.000000 手续费：16.8392
# 买入执行 价格：83999.90 数量：1.000000 手续费：16.8000
# 买入执行 价格：83999.90 数量：1.000000 手续费：16.8000
# 卖出执行 价格：83930.30 数量：-1.000000 手续费：16.7861
# 卖出执行 价格：83930.30 数量：-1.000000 手续费：16.7861
# 买入执行 价格：83833.20 数量：1.000000 手续费：16.7666
# 买入执行 价格：83833.20 数量：1.000000 手续费：16.7666
# 卖出执行 价格：83920.40 数量：-1.000000 手续费：16.7841
# 卖出执行 价格：83920.40 数量：-1.000000 手续费：16.7841
# 买入执行 价格：83973.70 数量：1.000000 手续费：16.7947
# 买入执行 价格：83973.70 数量：1.000000 手续费：16.7947
# 卖出执行 价格：83900.00 数量：-1.000000 手续费：16.7800
# 卖出执行 价格：83900.00 数量：-1.000000 手续费：16.7800
# 买入执行 价格：83830.10 数量：1.000000 手续费：16.7660
# 买入执行 价格：83830.10 数量：1.000000 手续费：16.7660
# 卖出执行 价格：83909.80 数量：-1.000000 手续费：16.7820
# 卖出执行 价格：83909.80 数量：-1.000000 手续费：16.7820
# 买入执行 价格：83939.80 数量：1.000000 手续费：16.7880
# 买入执行 价格：83939.80 数量：1.000000 手续费：16.7880
# 卖出执行 价格：83883.90 数量：-1.000000 手续费：16.7768
# 卖出执行 价格：83883.90 数量：-1.000000 手续费：16.7768
# 买入执行 价格：83811.30 数量：1.000000 手续费：16.7623
# 买入执行 价格：83811.30 数量：1.000000 手续费：16.7623
# 卖出执行 价格：83881.90 数量：-1.000000 手续费：16.7764
# 卖出执行 价格：83881.90 数量：-1.000000 手续费：16.7764
# 买入执行 价格：83960.00 数量：1.000000 手续费：16.7920
# 买入执行 价格：83960.00 数量：1.000000 手续费：16.7920
# 卖出执行 价格：84099.30 数量：-1.000000 手续费：16.8199
# 卖出执行 价格：84099.30 数量：-1.000000 手续费：16.8199
# 买入执行 价格：84110.10 数量：1.000000 手续费：16.8220
# 买入执行 价格：84110.10 数量：1.000000 手续费：16.8220
# 卖出执行 价格：84189.10 数量：-1.000000 手续费：16.8378
# 卖出执行 价格：84189.10 数量：-1.000000 手续费：16.8378
# 买入执行 价格：84201.90 数量：1.000000 手续费：16.8404
# 买入执行 价格：84201.90 数量：1.000000 手续费：16.8404
# 卖出执行 价格：84133.00 数量：-1.000000 手续费：16.8266
# 卖出执行 价格：84133.00 数量：-1.000000 手续费：16.8266
# 买入执行 价格：84256.60 数量：1.000000 手续费：16.8513
# 买入执行 价格：84256.60 数量：1.000000 手续费：16.8513
# 卖出执行 价格：84296.40 数量：-1.000000 手续费：16.8593
# 卖出执行 价格：84296.40 数量：-1.000000 手续费：16.8593
# 买入执行 价格：84374.70 数量：1.000000 手续费：16.8749
# 买入执行 价格：84374.70 数量：1.000000 手续费：16.8749
# 卖出执行 价格：84238.00 数量：-1.000000 手续费：16.8476
# 卖出执行 价格：84238.00 数量：-1.000000 手续费：16.8476
# 买入执行 价格：84205.70 数量：1.000000 手续费：16.8411
# 买入执行 价格：84205.70 数量：1.000000 手续费：16.8411
# 卖出执行 价格：84141.60 数量：-1.000000 手续费：16.8283
# 卖出执行 价格：84141.60 数量：-1.000000 手续费：16.8283
# 买入执行 价格：84290.00 数量：1.000000 手续费：16.8580
# 买入执行 价格：84290.00 数量：1.000000 手续费：16.8580
# 卖出执行 价格：84299.90 数量：-1.000000 手续费：16.8600
# 卖出执行 价格：84299.90 数量：-1.000000 手续费：16.8600
# 买入执行 价格：84342.10 数量：1.000000 手续费：16.8684
# 买入执行 价格：84342.10 数量：1.000000 手续费：16.8684
# 卖出执行 价格：84334.10 数量：-1.000000 手续费：16.8668
# 卖出执行 价格：84334.10 数量：-1.000000 手续费：16.8668
# 买入执行 价格：84338.30 数量：1.000000 手续费：16.8677
# 买入执行 价格：84338.30 数量：1.000000 手续费：16.8677
# 卖出执行 价格：84300.00 数量：-1.000000 手续费：16.8600
# 卖出执行 价格：84300.00 数量：-1.000000 手续费：16.8600
# 买入执行 价格：84306.10 数量：1.000000 手续费：16.8612
# 买入执行 价格：84306.10 数量：1.000000 手续费：16.8612
# 卖出执行 价格：84357.00 数量：-1.000000 手续费：16.8714
# 卖出执行 价格：84357.00 数量：-1.000000 手续费：16.8714
# 买入执行 价格：84404.10 数量：1.000000 手续费：16.8808
# 买入执行 价格：84404.10 数量：1.000000 手续费：16.8808
# 卖出执行 价格：84405.60 数量：-1.000000 手续费：16.8811
# 卖出执行 价格：84405.60 数量：-1.000000 手续费：16.8811
# 买入执行 价格：84448.00 数量：1.000000 手续费：16.8896
# 买入执行 价格：84448.00 数量：1.000000 手续费：16.8896
# 卖出执行 价格：84425.70 数量：-1.000000 手续费：16.8851
# 卖出执行 价格：84425.70 数量：-1.000000 手续费：16.8851
# 买入执行 价格：84419.00 数量：1.000000 手续费：16.8838
# 买入执行 价格：84419.00 数量：1.000000 手续费：16.8838
# 卖出执行 价格：84388.30 数量：-1.000000 手续费：16.8777
# 卖出执行 价格：84388.30 数量：-1.000000 手续费：16.8777
# 买入执行 价格：84219.40 数量：1.000000 手续费：16.8439
# 买入执行 价格：84219.40 数量：1.000000 手续费：16.8439
# 卖出执行 价格：84150.30 数量：-1.000000 手续费：16.8301
# 卖出执行 价格：84150.30 数量：-1.000000 手续费：16.8301
# 买入执行 价格：84189.00 数量：1.000000 手续费：16.8378
# 买入执行 价格：84189.00 数量：1.000000 手续费：16.8378
# 卖出执行 价格：84200.10 数量：-1.000000 手续费：16.8400
# 卖出执行 价格：84200.10 数量：-1.000000 手续费：16.8400
# 买入执行 价格：84235.20 数量：1.000000 手续费：16.8470
# 买入执行 价格：84235.20 数量：1.000000 手续费：16.8470
# 卖出执行 价格：84402.10 数量：-1.000000 手续费：16.8804
# 卖出执行 价格：84402.10 数量：-1.000000 手续费：16.8804
# 买入执行 价格：84426.30 数量：1.000000 手续费：16.8853
# 买入执行 价格：84426.30 数量：1.000000 手续费：16.8853
# 卖出执行 价格：84401.90 数量：-1.000000 手续费：16.8804
# 卖出执行 价格：84401.90 数量：-1.000000 手续费：16.8804
# 买入执行 价格：84422.20 数量：1.000000 手续费：16.8844
# 买入执行 价格：84422.20 数量：1.000000 手续费：16.8844
# 卖出执行 价格：84375.80 数量：-1.000000 手续费：16.8752
# 卖出执行 价格：84375.80 数量：-1.000000 手续费：16.8752
# 买入执行 价格：84409.50 数量：1.000000 手续费：16.8819
# 买入执行 价格：84409.50 数量：1.000000 手续费：16.8819
# 卖出执行 价格：84395.90 数量：-1.000000 手续费：16.8792
# 卖出执行 价格：84395.90 数量：-1.000000 手续费：16.8792
# 买入执行 价格：84382.50 数量：1.000000 手续费：16.8765
# 买入执行 价格：84382.50 数量：1.000000 手续费：16.8765
# 卖出执行 价格：84409.10 数量：-1.000000 手续费：16.8818
# 卖出执行 价格：84409.10 数量：-1.000000 手续费：16.8818
# 买入执行 价格：84455.80 数量：1.000000 手续费：16.8912
# 买入执行 价格：84455.80 数量：1.000000 手续费：16.8912
# 卖出执行 价格：84384.00 数量：-1.000000 手续费：16.8768
# 卖出执行 价格：84384.00 数量：-1.000000 手续费：16.8768
# 买入执行 价格：84390.60 数量：1.000000 手续费：16.8781
# 买入执行 价格：84390.60 数量：1.000000 手续费：16.8781
# 卖出执行 价格：84324.10 数量：-1.000000 手续费：16.8648
# 卖出执行 价格：84324.10 数量：-1.000000 手续费：16.8648
# 买入执行 价格：84403.90 数量：1.000000 手续费：16.8808
# 买入执行 价格：84403.90 数量：1.000000 手续费：16.8808
# 卖出执行 价格：84356.00 数量：-1.000000 手续费：16.8712
# 卖出执行 价格：84356.00 数量：-1.000000 手续费：16.8712
# 买入执行 价格：84370.00 数量：1.000000 手续费：16.8740
# 买入执行 价格：84370.00 数量：1.000000 手续费：16.8740
# 卖出执行 价格：84328.30 数量：-1.000000 手续费：16.8657
# 卖出执行 价格：84328.30 数量：-1.000000 手续费：16.8657
# 买入执行 价格：84342.00 数量：1.000000 手续费：16.8684
# 买入执行 价格：84342.00 数量：1.000000 手续费：16.8684
# 卖出执行 价格：84342.10 数量：-1.000000 手续费：16.8684
# 卖出执行 价格：84342.10 数量：-1.000000 手续费：16.8684
# 买入执行 价格：84306.90 数量：1.000000 手续费：16.8614
# 买入执行 价格：84306.90 数量：1.000000 手续费：16.8614
# 卖出执行 价格：84255.70 数量：-1.000000 手续费：16.8511
# 卖出执行 价格：84255.70 数量：-1.000000 手续费：16.8511
# 买入执行 价格：84032.20 数量：1.000000 手续费：16.8064
# 买入执行 价格：84032.20 数量：1.000000 手续费：16.8064
# 卖出执行 价格：83970.40 数量：-1.000000 手续费：16.7941
# 卖出执行 价格：83970.40 数量：-1.000000 手续费：16.7941
# 买入执行 价格：83840.60 数量：1.000000 手续费：16.7681
# 买入执行 价格：83840.60 数量：1.000000 手续费：16.7681
# 卖出执行 价格：84016.60 数量：-1.000000 手续费：16.8033
# 卖出执行 价格：84016.60 数量：-1.000000 手续费：16.8033
# 买入执行 价格：84017.60 数量：1.000000 手续费：16.8035
# 买入执行 价格：84017.60 数量：1.000000 手续费：16.8035
# 卖出执行 价格：84288.00 数量：-1.000000 手续费：16.8576
# 卖出执行 价格：84288.00 数量：-1.000000 手续费：16.8576
# 买入执行 价格：84378.60 数量：1.000000 手续费：16.8757
# 买入执行 价格：84378.60 数量：1.000000 手续费：16.8757
# 卖出执行 价格：84324.10 数量：-1.000000 手续费：16.8648
# 卖出执行 价格：84324.10 数量：-1.000000 手续费：16.8648
# 买入执行 价格：84342.00 数量：1.000000 手续费：16.8684
# 买入执行 价格：84342.00 数量：1.000000 手续费：16.8684
# 卖出执行 价格：84344.00 数量：-1.000000 手续费：16.8688
# 卖出执行 价格：84344.00 数量：-1.000000 手续费：16.8688
# 买入执行 价格：84382.20 数量：1.000000 手续费：16.8764
# 买入执行 价格：84382.20 数量：1.000000 手续费：16.8764
# 卖出执行 价格：84342.80 数量：-1.000000 手续费：16.8686
# 卖出执行 价格：84342.80 数量：-1.000000 手续费：16.8686
# 买入执行 价格：84351.90 数量：1.000000 手续费：16.8704
# 买入执行 价格：84351.90 数量：1.000000 手续费：16.8704
# 卖出执行 价格：84334.20 数量：-1.000000 手续费：16.8668
# 卖出执行 价格：84334.20 数量：-1.000000 手续费：16.8668
# 买入执行 价格：84378.10 数量：1.000000 手续费：16.8756
# 买入执行 价格：84378.10 数量：1.000000 手续费：16.8756
# 卖出执行 价格：84332.20 数量：-1.000000 手续费：16.8664
# 卖出执行 价格：84332.20 数量：-1.000000 手续费：16.8664
# 买入执行 价格：84179.60 数量：1.000000 手续费：16.8359
# 买入执行 价格：84179.60 数量：1.000000 手续费：16.8359
# 卖出执行 价格：84275.90 数量：-1.000000 手续费：16.8552
# 卖出执行 价格：84275.90 数量：-1.000000 手续费：16.8552
# 买入执行 价格：84282.30 数量：1.000000 手续费：16.8565
# 买入执行 价格：84282.30 数量：1.000000 手续费：16.8565
# 卖出执行 价格：84184.60 数量：-1.000000 手续费：16.8369
# 卖出执行 价格：84184.60 数量：-1.000000 手续费：16.8369
# 买入执行 价格：84285.00 数量：1.000000 手续费：16.8570
# 买入执行 价格：84285.00 数量：1.000000 手续费：16.8570
# 卖出执行 价格：84227.90 数量：-1.000000 手续费：16.8456
# 卖出执行 价格：84227.90 数量：-1.000000 手续费：16.8456
# 买入执行 价格：84280.10 数量：1.000000 手续费：16.8560
# 买入执行 价格：84280.10 数量：1.000000 手续费：16.8560
# 卖出执行 价格：84253.60 数量：-1.000000 手续费：16.8507
# 卖出执行 价格：84253.60 数量：-1.000000 手续费：16.8507
# 买入执行 价格：84264.10 数量：1.000000 手续费：16.8528
# 买入执行 价格：84264.10 数量：1.000000 手续费：16.8528
# 卖出执行 价格：84202.00 数量：-1.000000 手续费：16.8404
# 卖出执行 价格：84202.00 数量：-1.000000 手续费：16.8404
# 买入执行 价格：83938.00 数量：1.000000 手续费：16.7876
# 买入执行 价格：83938.00 数量：1.000000 手续费：16.7876
# 卖出执行 价格：83949.80 数量：-1.000000 手续费：16.7900
# 卖出执行 价格：83949.80 数量：-1.000000 手续费：16.7900
# 买入执行 价格：83804.40 数量：1.000000 手续费：16.7609
# 买入执行 价格：83804.40 数量：1.000000 手续费：16.7609
# 卖出执行 价格：83729.90 数量：-1.000000 手续费：16.7460
# 卖出执行 价格：83729.90 数量：-1.000000 手续费：16.7460
# 买入执行 价格：82628.60 数量：1.000000 手续费：16.5257
# 买入执行 价格：82628.60 数量：1.000000 手续费：16.5257
# 卖出执行 价格：82485.90 数量：-1.000000 手续费：16.4972
# 卖出执行 价格：82485.90 数量：-1.000000 手续费：16.4972
# 买入执行 价格：82643.60 数量：1.000000 手续费：16.5287
# 买入执行 价格：82643.60 数量：1.000000 手续费：16.5287
# 卖出执行 价格：82672.30 数量：-1.000000 手续费：16.5345
# 卖出执行 价格：82672.30 数量：-1.000000 手续费：16.5345
# 买入执行 价格：82759.80 数量：1.000000 手续费：16.5520
# 买入执行 价格：82759.80 数量：1.000000 手续费：16.5520
# 卖出执行 价格：82894.00 数量：-1.000000 手续费：16.5788
# 卖出执行 价格：82894.00 数量：-1.000000 手续费：16.5788
# 买入执行 价格：82968.20 数量：1.000000 手续费：16.5936
# 买入执行 价格：82968.20 数量：1.000000 手续费：16.5936
# 卖出执行 价格：82733.80 数量：-1.000000 手续费：16.5468
# 卖出执行 价格：82733.80 数量：-1.000000 手续费：16.5468
# 买入执行 价格：82904.00 数量：1.000000 手续费：16.5808
# 买入执行 价格：82904.00 数量：1.000000 手续费：16.5808
# 卖出执行 价格：82702.30 数量：-1.000000 手续费：16.5405
# 卖出执行 价格：82702.30 数量：-1.000000 手续费：16.5405
# 买入执行 价格：82785.30 数量：1.000000 手续费：16.5571
# 买入执行 价格：82785.30 数量：1.000000 手续费：16.5571
# 卖出执行 价格：82779.90 数量：-1.000000 手续费：16.5560
# 卖出执行 价格：82779.90 数量：-1.000000 手续费：16.5560
# 买入执行 价格：82893.40 数量：1.000000 手续费：16.5787
# 买入执行 价格：82893.40 数量：1.000000 手续费：16.5787
# 卖出执行 价格：83272.00 数量：-1.000000 手续费：16.6544
# 卖出执行 价格：83272.00 数量：-1.000000 手续费：16.6544
# 买入执行 价格：83264.20 数量：1.000000 手续费：16.6528
# 买入执行 价格：83264.20 数量：1.000000 手续费：16.6528
# 卖出执行 价格：83852.30 数量：-1.000000 手续费：16.7705
# 卖出执行 价格：83852.30 数量：-1.000000 手续费：16.7705
# 买入执行 价格：83924.10 数量：1.000000 手续费：16.7848
# 买入执行 价格：83924.10 数量：1.000000 手续费：16.7848
# 卖出执行 价格：83790.50 数量：-1.000000 手续费：16.7581
# 卖出执行 价格：83790.50 数量：-1.000000 手续费：16.7581
# 买入执行 价格：83766.00 数量：1.000000 手续费：16.7532
# 买入执行 价格：83766.00 数量：1.000000 手续费：16.7532
# 卖出执行 价格：83680.30 数量：-1.000000 手续费：16.7361
# 卖出执行 价格：83680.30 数量：-1.000000 手续费：16.7361
# 买入执行 价格：83670.80 数量：1.000000 手续费：16.7342
# 买入执行 价格：83670.80 数量：1.000000 手续费：16.7342
# 卖出执行 价格：83903.90 数量：-1.000000 手续费：16.7808
# 卖出执行 价格：83903.90 数量：-1.000000 手续费：16.7808
# 买入执行 价格：83209.20 数量：1.000000 手续费：16.6418
# 买入执行 价格：83209.20 数量：1.000000 手续费：16.6418
# 卖出执行 价格：82980.80 数量：-1.000000 手续费：16.5962
# 卖出执行 价格：82980.80 数量：-1.000000 手续费：16.5962
# 买入执行 价格：83104.00 数量：1.000000 手续费：16.6208
# 买入执行 价格：83104.00 数量：1.000000 手续费：16.6208
# 卖出执行 价格：83075.70 数量：-1.000000 手续费：16.6151
# 卖出执行 价格：83075.70 数量：-1.000000 手续费：16.6151
# 买入执行 价格：83201.80 数量：1.000000 手续费：16.6404
# 买入执行 价格：83201.80 数量：1.000000 手续费：16.6404
# 卖出执行 价格：83097.60 数量：-1.000000 手续费：16.6195
# 卖出执行 价格：83097.60 数量：-1.000000 手续费：16.6195
# 买入执行 价格：83184.20 数量：1.000000 手续费：16.6368
# 买入执行 价格：83184.20 数量：1.000000 手续费：16.6368
# 卖出执行 价格：83251.90 数量：-1.000000 手续费：16.6504
# 卖出执行 价格：83251.90 数量：-1.000000 手续费：16.6504
# 买入执行 价格：83089.60 数量：1.000000 手续费：16.6179
# 买入执行 价格：83089.60 数量：1.000000 手续费：16.6179
# 卖出执行 价格：83045.70 数量：-1.000000 手续费：16.6091
# 卖出执行 价格：83045.70 数量：-1.000000 手续费：16.6091
# 买入执行 价格：82877.20 数量：1.000000 手续费：16.5754
# 买入执行 价格：82877.20 数量：1.000000 手续费：16.5754
# 卖出执行 价格：82688.60 数量：-1.000000 手续费：16.5377
# 卖出执行 价格：82688.60 数量：-1.000000 手续费：16.5377
# 买入执行 价格：82826.50 数量：1.000000 手续费：16.5653
# 买入执行 价格：82826.50 数量：1.000000 手续费：16.5653
# 卖出执行 价格：82765.90 数量：-1.000000 手续费：16.5532
# 卖出执行 价格：82765.90 数量：-1.000000 手续费：16.5532
# 买入执行 价格：82455.30 数量：1.000000 手续费：16.4911
# 买入执行 价格：82455.30 数量：1.000000 手续费：16.4911
# 卖出执行 价格：82413.80 数量：-1.000000 手续费：16.4828
# 卖出执行 价格：82413.80 数量：-1.000000 手续费：16.4828
# 买入执行 价格：82432.10 数量：1.000000 手续费：16.4864
# 买入执行 价格：82432.10 数量：1.000000 手续费：16.4864
# 卖出执行 价格：82357.60 数量：-1.000000 手续费：16.4715
# 卖出执行 价格：82357.60 数量：-1.000000 手续费：16.4715
# 买入执行 价格：82229.90 数量：1.000000 手续费：16.4460
# 买入执行 价格：82229.90 数量：1.000000 手续费：16.4460
# 卖出执行 价格：82578.10 数量：-1.000000 手续费：16.5156
# 卖出执行 价格：82578.10 数量：-1.000000 手续费：16.5156
# 买入执行 价格：82635.70 数量：1.000000 手续费：16.5271
# 买入执行 价格：82635.70 数量：1.000000 手续费：16.5271
# 卖出执行 价格：82808.10 数量：-1.000000 手续费：16.5616
# 卖出执行 价格：82808.10 数量：-1.000000 手续费：16.5616
# 买入执行 价格：82949.80 数量：1.000000 手续费：16.5900
# 买入执行 价格：82949.80 数量：1.000000 手续费：16.5900
# 卖出执行 价格：83023.30 数量：-1.000000 手续费：16.6047
# 卖出执行 价格：83023.30 数量：-1.000000 手续费：16.6047
# 买入执行 价格：83006.50 数量：1.000000 手续费：16.6013
# 买入执行 价格：83006.50 数量：1.000000 手续费：16.6013
# 卖出执行 价格：83183.80 数量：-1.000000 手续费：16.6368
# 卖出执行 价格：83183.80 数量：-1.000000 手续费：16.6368
# 买入执行 价格：83180.90 数量：1.000000 手续费：16.6362
# 买入执行 价格：83180.90 数量：1.000000 手续费：16.6362
# 卖出执行 价格：83160.00 数量：-1.000000 手续费：16.6320
# 卖出执行 价格：83160.00 数量：-1.000000 手续费：16.6320
# 买入执行 价格：83388.80 数量：1.000000 手续费：16.6778
# 买入执行 价格：83388.80 数量：1.000000 手续费：16.6778
# 卖出执行 价格：83490.30 数量：-1.000000 手续费：16.6981
# 卖出执行 价格：83490.30 数量：-1.000000 手续费：16.6981
# 买入执行 价格：83504.20 数量：1.000000 手续费：16.7008
# 买入执行 价格：83504.20 数量：1.000000 手续费：16.7008
# 卖出执行 价格：83485.00 数量：-1.000000 手续费：16.6970
# 卖出执行 价格：83485.00 数量：-1.000000 手续费：16.6970
# 买入执行 价格：83542.00 数量：1.000000 手续费：16.7084
# 买入执行 价格：83542.00 数量：1.000000 手续费：16.7084
# 卖出执行 价格：83747.70 数量：-1.000000 手续费：16.7495
# 卖出执行 价格：83747.70 数量：-1.000000 手续费：16.7495
# 买入执行 价格：83750.10 数量：1.000000 手续费：16.7500
# 买入执行 价格：83750.10 数量：1.000000 手续费：16.7500
# 卖出执行 价格：83636.50 数量：-1.000000 手续费：16.7273
# 卖出执行 价格：83636.50 数量：-1.000000 手续费：16.7273
# 买入执行 价格：83615.70 数量：1.000000 手续费：16.7231
# 买入执行 价格：83615.70 数量：1.000000 手续费：16.7231
# 卖出执行 价格：83434.70 数量：-1.000000 手续费：16.6869
# 卖出执行 价格：83434.70 数量：-1.000000 手续费：16.6869
# 买入执行 价格：83234.00 数量：1.000000 手续费：16.6468
# 买入执行 价格：83234.00 数量：1.000000 手续费：16.6468
# 卖出执行 价格：83215.80 数量：-1.000000 手续费：16.6432
# 卖出执行 价格：83215.80 数量：-1.000000 手续费：16.6432
# 买入执行 价格：83080.00 数量：1.000000 手续费：16.6160
# 买入执行 价格：83080.00 数量：1.000000 手续费：16.6160
# 卖出执行 价格：83269.80 数量：-1.000000 手续费：16.6540
# 卖出执行 价格：83269.80 数量：-1.000000 手续费：16.6540
# 买入执行 价格：83369.10 数量：1.000000 手续费：16.6738
# 买入执行 价格：83369.10 数量：1.000000 手续费：16.6738
# 卖出执行 价格：83492.00 数量：-1.000000 手续费：16.6984
# 卖出执行 价格：83492.00 数量：-1.000000 手续费：16.6984
# 买入执行 价格：83487.90 数量：1.000000 手续费：16.6976
# 买入执行 价格：83487.90 数量：1.000000 手续费：16.6976
# 卖出执行 价格：83535.90 数量：-1.000000 手续费：16.7072
# 卖出执行 价格：83535.90 数量：-1.000000 手续费：16.7072
# 买入执行 价格：83549.50 数量：1.000000 手续费：16.7099
# 买入执行 价格：83549.50 数量：1.000000 手续费：16.7099
# 卖出执行 价格：83641.90 数量：-1.000000 手续费：16.7284
# 卖出执行 价格：83641.90 数量：-1.000000 手续费：16.7284
# 买入执行 价格：83650.00 数量：1.000000 手续费：16.7300
# 买入执行 价格：83650.00 数量：1.000000 手续费：16.7300
# 卖出执行 价格：83544.60 数量：-1.000000 手续费：16.7089
# 卖出执行 价格：83544.60 数量：-1.000000 手续费：16.7089
# 买入执行 价格：83491.90 数量：1.000000 手续费：16.6984
# 买入执行 价格：83491.90 数量：1.000000 手续费：16.6984
# 卖出执行 价格：83359.30 数量：-1.000000 手续费：16.6719
# 卖出执行 价格：83359.30 数量：-1.000000 手续费：16.6719
# 买入执行 价格：83391.30 数量：1.000000 手续费：16.6783
# 买入执行 价格：83391.30 数量：1.000000 手续费：16.6783
# 卖出执行 价格：83265.30 数量：-1.000000 手续费：16.6531
# 卖出执行 价格：83265.30 数量：-1.000000 手续费：16.6531
# 买入执行 价格：83401.50 数量：1.000000 手续费：16.6803
# 买入执行 价格：83401.50 数量：1.000000 手续费：16.6803
# 卖出执行 价格：83560.10 数量：-1.000000 手续费：16.7120
# 卖出执行 价格：83560.10 数量：-1.000000 手续费：16.7120
# 买入执行 价格：83597.30 数量：1.000000 手续费：16.7195
# 买入执行 价格：83597.30 数量：1.000000 手续费：16.7195
# 卖出执行 价格：83337.10 数量：-1.000000 手续费：16.6674
# 卖出执行 价格：83337.10 数量：-1.000000 手续费：16.6674
# 买入执行 价格：83127.90 数量：1.000000 手续费：16.6256
# 买入执行 价格：83127.90 数量：1.000000 手续费：16.6256
# 卖出执行 价格：83050.20 数量：-1.000000 手续费：16.6100
# 卖出执行 价格：83050.20 数量：-1.000000 手续费：16.6100
# 买入执行 价格：83169.20 数量：1.000000 手续费：16.6338
# 买入执行 价格：83169.20 数量：1.000000 手续费：16.6338
# 卖出执行 价格：83021.80 数量：-1.000000 手续费：16.6044
# 卖出执行 价格：83021.80 数量：-1.000000 手续费：16.6044
# 买入执行 价格：82784.20 数量：1.000000 手续费：16.5568
# 买入执行 价格：82784.20 数量：1.000000 手续费：16.5568
# 卖出执行 价格：83043.00 数量：-1.000000 手续费：16.6086
# 卖出执行 价格：83043.00 数量：-1.000000 手续费：16.6086
# 买入执行 价格：83112.50 数量：1.000000 手续费：16.6225
# 买入执行 价格：83112.50 数量：1.000000 手续费：16.6225
# 卖出执行 价格：83210.50 数量：-1.000000 手续费：16.6421
# 卖出执行 价格：83210.50 数量：-1.000000 手续费：16.6421
# 买入执行 价格：83367.00 数量：1.000000 手续费：16.6734
# 买入执行 价格：83367.00 数量：1.000000 手续费：16.6734
# 卖出执行 价格：83584.50 数量：-1.000000 手续费：16.7169
# 卖出执行 价格：83584.50 数量：-1.000000 手续费：16.7169
# 买入执行 价格：83402.00 数量：1.000000 手续费：16.6804
# 买入执行 价格：83402.00 数量：1.000000 手续费：16.6804
# 卖出执行 价格：84193.80 数量：-1.000000 手续费：16.8388
# 卖出执行 价格：84193.80 数量：-1.000000 手续费：16.8388
# 买入执行 价格：84188.20 数量：1.000000 手续费：16.8376
# 买入执行 价格：84188.20 数量：1.000000 手续费：16.8376
# 卖出执行 价格：84129.90 数量：-1.000000 手续费：16.8260
# 卖出执行 价格：84129.90 数量：-1.000000 手续费：16.8260
# 买入执行 价格：84259.40 数量：1.000000 手续费：16.8519
# 买入执行 价格：84259.40 数量：1.000000 手续费：16.8519
# 卖出执行 价格：84458.00 数量：-1.000000 手续费：16.8916
# 卖出执行 价格：84458.00 数量：-1.000000 手续费：16.8916
# 买入执行 价格：84462.40 数量：1.000000 手续费：16.8925
# 买入执行 价格：84462.40 数量：1.000000 手续费：16.8925
# 卖出执行 价格：84417.70 数量：-1.000000 手续费：16.8835
# 卖出执行 价格：84417.70 数量：-1.000000 手续费：16.8835
# 买入执行 价格：84464.90 数量：1.000000 手续费：16.8930
# 买入执行 价格：84464.90 数量：1.000000 手续费：16.8930
# 卖出执行 价格：84477.30 数量：-1.000000 手续费：16.8955
# 卖出执行 价格：84477.30 数量：-1.000000 手续费：16.8955
# 买入执行 价格：84127.90 数量：1.000000 手续费：16.8256
# 买入执行 价格：84127.90 数量：1.000000 手续费：16.8256
# 卖出执行 价格：83966.30 数量：-1.000000 手续费：16.7933
# 卖出执行 价格：83966.30 数量：-1.000000 手续费：16.7933
# 买入执行 价格：84060.20 数量：1.000000 手续费：16.8120
# 买入执行 价格：84060.20 数量：1.000000 手续费：16.8120
# 卖出执行 价格：83966.60 数量：-1.000000 手续费：16.7933
# 卖出执行 价格：83966.60 数量：-1.000000 手续费：16.7933
# 买入执行 价格：83993.80 数量：1.000000 手续费：16.7988
# 买入执行 价格：83993.80 数量：1.000000 手续费：16.7988
# 卖出执行 价格：84015.70 数量：-1.000000 手续费：16.8031
# 卖出执行 价格：84015.70 数量：-1.000000 手续费：16.8031
# 买入执行 价格：84118.00 数量：1.000000 手续费：16.8236
# 买入执行 价格：84118.00 数量：1.000000 手续费：16.8236
# 卖出执行 价格：84168.20 数量：-1.000000 手续费：16.8336
# 卖出执行 价格：84168.20 数量：-1.000000 手续费：16.8336
# 买入执行 价格：83964.20 数量：1.000000 手续费：16.7928
# 买入执行 价格：83964.20 数量：1.000000 手续费：16.7928
# 卖出执行 价格：84011.90 数量：-1.000000 手续费：16.8024
# 卖出执行 价格：84011.90 数量：-1.000000 手续费：16.8024
# 买入执行 价格：83838.60 数量：1.000000 手续费：16.7677
# 买入执行 价格：83838.60 数量：1.000000 手续费：16.7677
# 卖出执行 价格：83760.10 数量：-1.000000 手续费：16.7520
# 卖出执行 价格：83760.10 数量：-1.000000 手续费：16.7520
# 买入执行 价格：83799.00 数量：1.000000 手续费：16.7598
# 买入执行 价格：83799.00 数量：1.000000 手续费：16.7598
# 卖出执行 价格：83736.40 数量：-1.000000 手续费：16.7473
# 卖出执行 价格：83736.40 数量：-1.000000 手续费：16.7473
# 买入执行 价格：83166.60 数量：1.000000 手续费：16.6333
# 买入执行 价格：83166.60 数量：1.000000 手续费：16.6333
# 卖出执行 价格：83317.90 数量：-1.000000 手续费：16.6636
# 卖出执行 价格：83317.90 数量：-1.000000 手续费：16.6636
# 买入执行 价格：83447.90 数量：1.000000 手续费：16.6896
# 买入执行 价格：83447.90 数量：1.000000 手续费：16.6896
# 卖出执行 价格：83362.00 数量：-1.000000 手续费：16.6724
# 卖出执行 价格：83362.00 数量：-1.000000 手续费：16.6724
# 买入执行 价格：83468.80 数量：1.000000 手续费：16.6938
# 买入执行 价格：83468.80 数量：1.000000 手续费：16.6938
# 卖出执行 价格：83390.10 数量：-1.000000 手续费：16.6780
# 卖出执行 价格：83390.10 数量：-1.000000 手续费：16.6780
# 买入执行 价格：83452.60 数量：1.000000 手续费：16.6905
# 买入执行 价格：83452.60 数量：1.000000 手续费：16.6905
# 卖出执行 价格：83376.00 数量：-1.000000 手续费：16.6752
# 卖出执行 价格：83376.00 数量：-1.000000 手续费：16.6752
# 买入执行 价格：83277.20 数量：1.000000 手续费：16.6554
# 买入执行 价格：83277.20 数量：1.000000 手续费：16.6554
# 卖出执行 价格：83091.50 数量：-1.000000 手续费：16.6183
# 卖出执行 价格：83091.50 数量：-1.000000 手续费：16.6183
# 买入执行 价格：83153.30 数量：1.000000 手续费：16.6307
# 买入执行 价格：83153.30 数量：1.000000 手续费：16.6307
# 卖出执行 价格：83153.60 数量：-1.000000 手续费：16.6307
# 卖出执行 价格：83153.60 数量：-1.000000 手续费：16.6307
# 买入执行 价格：83196.00 数量：1.000000 手续费：16.6392
# 买入执行 价格：83196.00 数量：1.000000 手续费：16.6392
# 卖出执行 价格：83107.90 数量：-1.000000 手续费：16.6216
# 卖出执行 价格：83107.90 数量：-1.000000 手续费：16.6216
# 买入执行 价格：83181.90 数量：1.000000 手续费：16.6364
# 买入执行 价格：83181.90 数量：1.000000 手续费：16.6364
# 卖出执行 价格：83080.20 数量：-1.000000 手续费：16.6160
# 卖出执行 价格：83080.20 数量：-1.000000 手续费：16.6160
# 买入执行 价格：82993.80 数量：1.000000 手续费：16.5988
# 买入执行 价格：82993.80 数量：1.000000 手续费：16.5988
# 卖出执行 价格：83003.40 数量：-1.000000 手续费：16.6007
# 卖出执行 价格：83003.40 数量：-1.000000 手续费：16.6007
# 买入执行 价格：83006.10 数量：1.000000 手续费：16.6012
# 买入执行 价格：83006.10 数量：1.000000 手续费：16.6012
# 卖出执行 价格：82953.50 数量：-1.000000 手续费：16.5907
# 卖出执行 价格：82953.50 数量：-1.000000 手续费：16.5907
# 买入执行 价格：83047.70 数量：1.000000 手续费：16.6095
# 买入执行 价格：83047.70 数量：1.000000 手续费：16.6095
# 卖出执行 价格：82964.00 数量：-1.000000 手续费：16.5928
# 卖出执行 价格：82964.00 数量：-1.000000 手续费：16.5928
# 买入执行 价格：82457.60 数量：1.000000 手续费：16.4915
# 买入执行 价格：82457.60 数量：1.000000 手续费：16.4915
# 卖出执行 价格：83027.50 数量：-1.000000 手续费：16.6055
# 卖出执行 价格：83027.50 数量：-1.000000 手续费：16.6055
# 买入执行 价格：83100.60 数量：1.000000 手续费：16.6201
# 买入执行 价格：83100.60 数量：1.000000 手续费：16.6201
# 卖出执行 价格：83076.60 数量：-1.000000 手续费：16.6153
# 卖出执行 价格：83076.60 数量：-1.000000 手续费：16.6153
# 买入执行 价格：83129.90 数量：1.000000 手续费：16.6260
# 买入执行 价格：83129.90 数量：1.000000 手续费：16.6260
# 卖出执行 价格：83096.80 数量：-1.000000 手续费：16.6194
# 卖出执行 价格：83096.80 数量：-1.000000 手续费：16.6194
# 买入执行 价格：83189.80 数量：1.000000 手续费：16.6380
# 买入执行 价格：83189.80 数量：1.000000 手续费：16.6380
# 卖出执行 价格：83285.20 数量：-1.000000 手续费：16.6570
# 卖出执行 价格：83285.20 数量：-1.000000 手续费：16.6570
# 买入执行 价格：83352.70 数量：1.000000 手续费：16.6705
# 买入执行 价格：83352.70 数量：1.000000 手续费：16.6705
# 卖出执行 价格：83266.60 数量：-1.000000 手续费：16.6533
# 卖出执行 价格：83266.60 数量：-1.000000 手续费：16.6533
# 买入执行 价格：83172.60 数量：1.000000 手续费：16.6345
# 买入执行 价格：83172.60 数量：1.000000 手续费：16.6345
# 卖出执行 价格：83136.10 数量：-1.000000 手续费：16.6272
# 卖出执行 价格：83136.10 数量：-1.000000 手续费：16.6272
# 买入执行 价格：82752.00 数量：1.000000 手续费：16.5504
# 买入执行 价格：82752.00 数量：1.000000 手续费：16.5504
# 卖出执行 价格：82639.30 数量：-1.000000 手续费：16.5279
# 卖出执行 价格：82639.30 数量：-1.000000 手续费：16.5279
# 买入执行 价格：82826.10 数量：1.000000 手续费：16.5652
# 买入执行 价格：82826.10 数量：1.000000 手续费：16.5652
# 卖出执行 价格：82815.60 数量：-1.000000 手续费：16.5631
# 卖出执行 价格：82815.60 数量：-1.000000 手续费：16.5631
# 买入执行 价格：82787.30 数量：1.000000 手续费：16.5575
# 买入执行 价格：82787.30 数量：1.000000 手续费：16.5575
# 卖出执行 价格：82718.30 数量：-1.000000 手续费：16.5437
# 卖出执行 价格：82718.30 数量：-1.000000 手续费：16.5437
# 买入执行 价格：82760.20 数量：1.000000 手续费：16.5520
# 买入执行 价格：82760.20 数量：1.000000 手续费：16.5520
# 卖出执行 价格：82700.10 数量：-1.000000 手续费：16.5400
# 卖出执行 价格：82700.10 数量：-1.000000 手续费：16.5400
# 买入执行 价格：82580.90 数量：1.000000 手续费：16.5162
# 买入执行 价格：82580.90 数量：1.000000 手续费：16.5162
# 卖出执行 价格：82528.20 数量：-1.000000 手续费：16.5056
# 卖出执行 价格：82528.20 数量：-1.000000 手续费：16.5056
# 买入执行 价格：82650.70 数量：1.000000 手续费：16.5301
# 买入执行 价格：82650.70 数量：1.000000 手续费：16.5301
# 卖出执行 价格：82620.90 数量：-1.000000 手续费：16.5242
# 卖出执行 价格：82620.90 数量：-1.000000 手续费：16.5242
# 买入执行 价格：82411.40 数量：1.000000 手续费：16.4823
# 买入执行 价格：82411.40 数量：1.000000 手续费：16.4823
# 卖出执行 价格：82320.10 数量：-1.000000 手续费：16.4640
# 卖出执行 价格：82320.10 数量：-1.000000 手续费：16.4640
# 买入执行 价格：82378.00 数量：1.000000 手续费：16.4756
# 买入执行 价格：82378.00 数量：1.000000 手续费：16.4756
# 卖出执行 价格：82122.10 数量：-1.000000 手续费：16.4244
# 卖出执行 价格：82122.10 数量：-1.000000 手续费：16.4244
# 买入执行 价格：81534.00 数量：1.000000 手续费：16.3068
# 买入执行 价格：81534.00 数量：1.000000 手续费：16.3068
# 卖出执行 价格：81268.10 数量：-1.000000 手续费：16.2536
# 卖出执行 价格：81268.10 数量：-1.000000 手续费：16.2536
# 买入执行 价格：81448.00 数量：1.000000 手续费：16.2896
# 买入执行 价格：81448.00 数量：1.000000 手续费：16.2896
# 卖出执行 价格：81550.10 数量：-1.000000 手续费：16.3100
# 卖出执行 价格：81550.10 数量：-1.000000 手续费：16.3100
# 买入执行 价格：81791.50 数量：1.000000 手续费：16.3583
# 买入执行 价格：81791.50 数量：1.000000 手续费：16.3583
# 卖出执行 价格：81674.20 数量：-1.000000 手续费：16.3348
# 卖出执行 价格：81674.20 数量：-1.000000 手续费：16.3348
# 买入执行 价格：81764.00 数量：1.000000 手续费：16.3528
# 买入执行 价格：81764.00 数量：1.000000 手续费：16.3528
# 卖出执行 价格：81656.50 数量：-1.000000 手续费：16.3313
# 卖出执行 价格：81656.50 数量：-1.000000 手续费：16.3313
# 买入执行 价格：81708.40 数量：1.000000 手续费：16.3417
# 买入执行 价格：81708.40 数量：1.000000 手续费：16.3417
# 卖出执行 价格：81876.10 数量：-1.000000 手续费：16.3752
# 卖出执行 价格：81876.10 数量：-1.000000 手续费：16.3752
# 买入执行 价格：81842.30 数量：1.000000 手续费：16.3685
# 买入执行 价格：81842.30 数量：1.000000 手续费：16.3685
# 卖出执行 价格：81706.10 数量：-1.000000 手续费：16.3412
# 卖出执行 价格：81706.10 数量：-1.000000 手续费：16.3412
# 买入执行 价格：81864.40 数量：1.000000 手续费：16.3729
# 买入执行 价格：81864.40 数量：1.000000 手续费：16.3729
# 卖出执行 价格：81620.80 数量：-1.000000 手续费：16.3242
# 卖出执行 价格：81620.80 数量：-1.000000 手续费：16.3242
# 买入执行 价格：81828.50 数量：1.000000 手续费：16.3657
# 买入执行 价格：81828.50 数量：1.000000 手续费：16.3657
# 卖出执行 价格：81557.20 数量：-1.000000 手续费：16.3114
# 卖出执行 价格：81557.20 数量：-1.000000 手续费：16.3114
# 买入执行 价格：81482.80 数量：1.000000 手续费：16.2966
# 买入执行 价格：81482.80 数量：1.000000 手续费：16.2966
# 卖出执行 价格：81405.40 数量：-1.000000 手续费：16.2811
# 卖出执行 价格：81405.40 数量：-1.000000 手续费：16.2811
# 买入执行 价格：81569.40 数量：1.000000 手续费：16.3139
# 买入执行 价格：81569.40 数量：1.000000 手续费：16.3139
# 卖出执行 价格：81357.40 数量：-1.000000 手续费：16.2715
# 卖出执行 价格：81357.40 数量：-1.000000 手续费：16.2715
# 买入执行 价格：81497.00 数量：1.000000 手续费：16.2994
# 买入执行 价格：81497.00 数量：1.000000 手续费：16.2994
# 卖出执行 价格：81910.00 数量：-1.000000 手续费：16.3820
# 卖出执行 价格：81910.00 数量：-1.000000 手续费：16.3820
# 买入执行 价格：82011.30 数量：1.000000 手续费：16.4023
# 买入执行 价格：82011.30 数量：1.000000 手续费：16.4023
# 卖出执行 价格：82112.00 数量：-1.000000 手续费：16.4224
# 卖出执行 价格：82112.00 数量：-1.000000 手续费：16.4224
# 买入执行 价格：82012.80 数量：1.000000 手续费：16.4026
# 买入执行 价格：82012.80 数量：1.000000 手续费：16.4026
# 卖出执行 价格：82080.10 数量：-1.000000 手续费：16.4160
# 卖出执行 价格：82080.10 数量：-1.000000 手续费：16.4160
# 买入执行 价格：82055.30 数量：1.000000 手续费：16.4111
# 买入执行 价格：82055.30 数量：1.000000 手续费：16.4111
# 卖出执行 价格：82243.90 数量：-1.000000 手续费：16.4488
# 卖出执行 价格：82243.90 数量：-1.000000 手续费：16.4488
# 买入执行 价格：82348.80 数量：1.000000 手续费：16.4698
# 买入执行 价格：82348.80 数量：1.000000 手续费：16.4698
# 卖出执行 价格：82618.30 数量：-1.000000 手续费：16.5237
# 卖出执行 价格：82618.30 数量：-1.000000 手续费：16.5237
# 买入执行 价格：82794.00 数量：1.000000 手续费：16.5588
# 买入执行 价格：82794.00 数量：1.000000 手续费：16.5588
# 卖出执行 价格：82656.70 数量：-1.000000 手续费：16.5313
# 卖出执行 价格：82656.70 数量：-1.000000 手续费：16.5313
# 买入执行 价格：82710.00 数量：1.000000 手续费：16.5420
# 买入执行 价格：82710.00 数量：1.000000 手续费：16.5420
# 卖出执行 价格：83022.30 数量：-1.000000 手续费：16.6045
# 卖出执行 价格：83022.30 数量：-1.000000 手续费：16.6045
# 买入执行 价格：82886.00 数量：1.000000 手续费：16.5772
# 买入执行 价格：82886.00 数量：1.000000 手续费：16.5772
# 卖出执行 价格：82886.00 数量：-1.000000 手续费：16.5772
# 卖出执行 价格：82886.00 数量：-1.000000 手续费：16.5772
# 买入执行 价格：82739.10 数量：1.000000 手续费：16.5478
# 买入执行 价格：82739.10 数量：1.000000 手续费：16.5478
# 卖出执行 价格：82679.90 数量：-1.000000 手续费：16.5360
# 卖出执行 价格：82679.90 数量：-1.000000 手续费：16.5360
# 买入执行 价格：82795.70 数量：1.000000 手续费：16.5591
# 买入执行 价格：82795.70 数量：1.000000 手续费：16.5591
# 卖出执行 价格：82892.60 数量：-1.000000 手续费：16.5785
# 卖出执行 价格：82892.60 数量：-1.000000 手续费：16.5785
# 买入执行 价格：82915.90 数量：1.000000 手续费：16.5832
# 买入执行 价格：82915.90 数量：1.000000 手续费：16.5832
# 卖出执行 价格：82859.60 数量：-1.000000 手续费：16.5719
# 卖出执行 价格：82859.60 数量：-1.000000 手续费：16.5719
# 买入执行 价格：82992.00 数量：1.000000 手续费：16.5984
# 买入执行 价格：82992.00 数量：1.000000 手续费：16.5984
# 卖出执行 价格：82920.30 数量：-1.000000 手续费：16.5841
# 卖出执行 价格：82920.30 数量：-1.000000 手续费：16.5841
# 买入执行 价格：82956.30 数量：1.000000 手续费：16.5913
# 买入执行 价格：82956.30 数量：1.000000 手续费：16.5913
# 卖出执行 价格：82960.00 数量：-1.000000 手续费：16.5920
# 卖出执行 价格：82960.00 数量：-1.000000 手续费：16.5920
# 买入执行 价格：82966.60 数量：1.000000 手续费：16.5933
# 买入执行 价格：82966.60 数量：1.000000 手续费：16.5933
# 卖出执行 价格：82921.90 数量：-1.000000 手续费：16.5844
# 卖出执行 价格：82921.90 数量：-1.000000 手续费：16.5844
# 买入执行 价格：83003.40 数量：1.000000 手续费：16.6007
# 买入执行 价格：83003.40 数量：1.000000 手续费：16.6007
# 最终净值：87848.33
# 总交易次数： 1069
# <div id='180f67f3-2406-4fbb-aaeb-2b2f881228c2'></div>

# %%
import numpy as np
class BollingerStrategy:
    def __init__(self, 
                 bb_window=20,
                 bb_std_mult=3,
                 position_ratio=0.1,
                 leverage=10,
                 take_profit_ratio=0.01,
                 stop_loss_ratio=0.01):
        
        # 策略参数
        self.bb_window = bb_window
        self.bb_std_mult = bb_std_mult
        self.position_ratio = position_ratio
        self.leverage = leverage
        self.tp_ratio = take_profit_ratio
        self.sl_ratio = stop_loss_ratio
        
        # 数据缓存
        self.price_buffer = []
        self.indicators = {
            'ma': [],
            'upper': [],
            'lower': []
        }

    def next(self, price, balance):
        """
        输入最新价格数据并生成信号
        :param price: dict 包含'open','high','low','close'
        :param balance: 当前账户余额
        :return: dict 交易信号
        """
        self._update_indicators(price)
        
        if len(self.price_buffer) < self.bb_window:
            return {'signal': 0}
            
        signal_info = self._generate_signal(price, balance)
        return signal_info

    def _update_indicators(self, price):
        # 更新价格数据
        self.price_buffer.append(price['close'])
        
        # 维护固定长度窗口
        if len(self.price_buffer) > self.bb_window:
            self.price_buffer.pop(0)
        
        # 计算布林带
        if len(self.price_buffer) == self.bb_window:
            ma = np.mean(self.price_buffer)
            std = np.std(self.price_buffer)
            upper = ma + std * self.bb_std_mult
            lower = ma - std * self.bb_std_mult
        else:
            ma = upper = lower = None
            
        self.indicators['ma'].append(ma)
        self.indicators['upper'].append(upper)
        self.indicators['lower'].append(lower)

    def _generate_signal(self, price, balance):
        # 获取当前和前一根的指标值
        curr_upper = self.indicators['upper'][-1]
        curr_lower = self.indicators['lower'][-1]
        prev_upper = self.indicators['upper'][-2] if len(self.indicators['upper']) >=2 else None
        prev_lower = self.indicators['lower'][-2] if len(self.indicators['lower']) >=2 else None

        signal = 0
        # 做空信号
        if price['high'] >= curr_upper and price['high'] > prev_upper:
            signal = -1
            
        # 做多信号
        elif price['low'] <= curr_lower and price['low'] < prev_lower:
            signal = 1
            
        if signal == 0:
            return {'signal': 0}
        
        # 计算仓位
        position_value = balance * self.position_ratio * self.leverage
        position_size = position_value / price['close']
        
        # 计算止盈止损
        entry_price = price['close']
        if signal == 1:
            tp = entry_price * (1 + self.tp_ratio)
            sl = entry_price * (1 - self.sl_ratio)
        else:
            tp = entry_price * (1 - self.tp_ratio)
            sl = entry_price * (1 + self.sl_ratio)
            
        return {
            'signal': signal,
            'size': position_size,
            'tp': tp,
            'sl': sl,
            'entry_price': entry_price
        }
class Backtester:
    def __init__(self, data, strategy):
        self.data = data
        self.strategy = strategy
        self.equity = [10000]  # 初始资金
        self.position = {
            'size': 0,
            'entry_price': 0,
            'direction': 0,  # 1: 多 -1: 空
            'tp': 0,
            'sl': 0
        }

    def run_backtest(self):
        for i, row in self.data.iterrows():
            # 获取当前资金
            current_balance = self.equity[-1]
            
            # 生成信号（每根K线开始时）
            signal_info = self.strategy.next(
                price={
                    'open': row['open'],
                    'high': row['high'],
                    'low': row['low'],
                    'close': row['close']
                },
                balance=current_balance
            )
            
            # 检查止损止盈（每根K线开始时）
            if self.position['size'] > 0:
                self._check_exit_conditions(row)
            
            # 执行新信号（无持仓时）
            if signal_info['signal'] != 0 and self.position['size'] == 0:
                self._execute_trade(signal_info, row)
            
            # 更新权益曲线（每根K线结束时）
            self._update_equity(row)

    def _execute_trade(self, signal, row):
        self.position = {
            'size': signal['size'],
            'entry_price': signal['entry_price'],
            'direction': signal['signal'],
            'tp': signal['tp'],
            'sl': signal['sl']
        }

    def _check_exit_conditions(self, row):
        current_low = row['low']
        current_high = row['high']
        
        if self.position['direction'] == 1:  # 多单
            # 止损检查（当日最低价触发）
            if current_low <= self.position['sl']:
                self._close_position(self.position['sl'])
            # 止盈检查（当日最高价触发）
            elif current_high >= self.position['tp']:
                self._close_position(self.position['tp'])
                
        elif self.position['direction'] == -1:  # 空单
            if current_high >= self.position['sl']:
                self._close_position(self.position['sl'])
            elif current_low <= self.position['tp']:
                self._close_position(self.position['tp'])

    def _close_position(self, exit_price):
        # 计算盈亏
        if self.position['direction'] == 1:
            pnl = (exit_price - self.position['entry_price']) * self.position['size']
        else:
            pnl = (self.position['entry_price'] - exit_price) * self.position['size']
        
        # 更新权益
        self.equity[-1] += pnl
        # 重置持仓
        self.position = {'size':0, 'entry_price':0, 'direction':0, 'tp':0, 'sl':0}

    def _update_equity(self, row):
        # 计算浮动盈亏
        if self.position['size'] > 0:
            mark_price = row['close']
            if self.position['direction'] == 1:
                unrealized = (mark_price - self.position['entry_price']) * self.position['size']
            else:
                unrealized = (self.position['entry_price'] - mark_price) * self.position['size']
            self.equity.append(self.equity[-1] + unrealized)
        else:
            self.equity.append(self.equity[-1])
# 准备数据（示例）
import pandas as pd
data = df = fetch_kline_bt(days=7, bar="5m", instId="BTC-USDT")

# 初始化策略
strategy = BollingerStrategy(
    bb_window=20,
    bb_std_mult=2.5,
    position_ratio=0.2,
    leverage=10,
    take_profit_ratio=0.03,
    stop_loss_ratio=0.02
)

# 运行回测
backtester = Backtester(data, strategy)
backtester.run_backtest()

# 获取结果
print(f"最终资金：{backtester.equity[-1]:.2f}")
# Out:
# 最终资金：-6685.93
